# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from scrape import get_user_anime

# %%
# Reading users
users1 = pd.read_csv("clean_data/users1.csv") # each row is a user, each column is an anime (each cell contains the users score of that anime)
users2 = pd.read_csv("clean_data/users2.csv")
users3 = pd.read_csv("clean_data/users3.csv")
users4 = pd.read_csv("clean_data/users4.csv")

# Concatenating Dataframes and computing total watchers

users = pd.concat([users1, users2, users3, users4],ignore_index=True)
users_array = users.to_numpy()

total_watchers = np.ceil(np.sum(users_array, axis=0) / 10.0)
total_watchers = np.maximum(np.ones(len(total_watchers)), total_watchers)

# %%
d = {}
d['One Punch Man'] = 30276
d['Death Note'] = 1535
d['Shingeki no Kyojin'] = 16498
d['Angel Beats!'] = 6547
d['Tengen Toppa Gurren Lagann'] = 2001
d['Kimi no Na wa'] = 32281
d['Haikyuu!!'] = 20583
d['Haikyuu!! Second Season'] = 28891
d['Noragami'] = 20507
d['Made in Abyss'] = 34599
d['Planetus'] = 329
d['Hunter x Hunter (2011)'] = 11061
d['Boku no Hero Academia'] = 31964
d['Fairy Tail'] = 6702

# %%
all_anime = pd.read_csv("data/AnimeList.csv")

anime_id_map_reverse = np.loadtxt("clean_data/anime_id_map_reverse.csv").astype(np.int)
anime_id_map = {}
for idx in range(len(anime_id_map_reverse)):
    anime_id_map[anime_id_map_reverse[idx]] = idx

# %%
def convert_raw(data):
    out = []
    for row in data:
        if (row["anime_id"] in anime_id_map_reverse):
            out.append(row)
    return out

# %%
usernames = ["greenmythos", "fingoldin"]
test_users = [ convert_raw(get_user_anime(username)) for username in usernames ]

# %%
test_users = [ [
  { "anime_id": d['Shingeki no Kyojin'], "score": 8.0 },
  { "anime_id": d['One Punch Man'], "score": 6.0 },
  { "anime_id": 21, "score": 8.0 }
  ],
  [{ "anime_id": d['Angel Beats!'], "score": 10.0 }],
  [{ "anime_id": d['Kimi no Na wa'], "score": 10.0 }],
  [
  { "anime_id": d['Angel Beats!'], "score": 10.0 },
  { "anime_id": d['Kimi no Na wa'], "score": 10.0 }
  ],
  [
  { "anime_id": d['Shingeki no Kyojin'], "score": 9.0 },
  { "anime_id": d['Death Note'], "score": 10.0 },
  { "anime_id": d['Tengen Toppa Gurren Lagann'], "score": 10.0 },
  { "anime_id": d['One Punch Man'], "score": 10.0 }
  ],
  [
  { "anime_id": d['Haikyuu!!'], "score": 10.0 },
  { "anime_id": d['Haikyuu!! Second Season'], "score": 10.0 }
  ],
  [{ "anime_id": d['Planetus'], "score": 10.0 }],
  [
  { "anime_id": d['Noragami'], "score": 9.0 },
  { "anime_id": d['Made in Abyss'], "score": 10.0 },
  { "anime_id": d['Hunter x Hunter (2011)'], "score": 10.0 },
  { "anime_id": d['Boku no Hero Academia'], "score": 10.0 },
  { "anime_id": d['Fairy Tail'], "score": 8.0 }
  ]
]

# %%
def kernel(user1, user2, penalty=2.0):
    product = np.ceil(user1/10.0) * np.ceil(user2/10.0)
    dif = penalty * (user1 - user2) * product
    n = np.sum(product)
    return math.exp(-math.sqrt(np.sum(dif * dif))/n) if n != 0 else 0

def predict(test_user,scale=1.0,threshold=0.0,variety=0.85,penalty=2.0):
    anime = np.zeros(len(test_user))
    watchers = np.power(total_watchers,variety)
    for user in users_array:
        s = kernel(test_user, user, penalty)
        temp = np.power(user,scale)
        anime = anime + s * (temp - np.ceil(user/10.0) * math.pow(threshold,scale))
    anime = anime / watchers

    anime = (1 - np.ceil(test_user / 10.0)) * anime
    best_anime_idx = np.argpartition(anime, -10)[-10:]
    best_anime = anime[best_anime_idx]
    best_anime = np.stack((best_anime.T, best_anime_idx.T)).T
    best_anime_idx = best_anime[best_anime[:,0].argsort()[::-1]][:,1].T
    return np.array(best_anime_idx,dtype=np.int)

def convert_test(test_user):
    test_vector = np.zeros(len(users.columns))
    for anime in test_user:
        test_vector[anime_id_map[anime["anime_id"]]] = anime["score"]

    return test_vector

def convert_predict(anime_id):
    return all_anime[all_anime["anime_id"] == anime_id_map_reverse[anime_id]].iloc[0]["title"]

# %%
def full_predict(test_users,scale=1.0,threshold=0.0,variety=0.85,penalty=2.0):
    print("Variety: ", variety, "  Scale: ", scale, "  Threshold: ", threshold, "  Penalty: ", penalty)
    for test_user in test_users:
        pred = predict(convert_test(test_user),scale,threshold,variety,penalty)
        string = ''
        for i in range(len(pred)):
            string += str(i+1) + '. ' + convert_predict(pred[i]) + "   "
        print(string + '\n')

# %%
for i in range(4):
    for j in range(4):
        full_predict(test_users, 1.0 - j/12, 0.0 + j, 0.6 + 0.1 * i, 2.0)
# Out:
# Variety:  0.6
# Scale:  1.0
# Threshold:  0.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Sword Art Online   3. Steins;Gate   4. Sen to Chihiro no Kamikakushi   5. Clannad   6. Fullmetal Alchemist   7. No Game No Life   8. Naruto   9. Elfen Lied   10. Durarara!!
#
# 1. Death Note   2. Shingeki no Kyojin   3. Sen to Chihiro no Kamikakushi   4. Steins;Gate   5. Fullmetal Alchemist: Brotherhood   6. Code Geass: Hangyaku no Lelouch   7. Angel Beats!   8. Toradora!   9. Code Geass: Hangyaku no Lelouch R2   10. Sword Art Online
#
# Variety:  0.6
# Scale:  0.9166666666666666
# Threshold:  1.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Sword Art Online   3. Steins;Gate   4. Sen to Chihiro no Kamikakushi   5. Clannad   6. Fullmetal Alchemist   7. No Game No Life   8. Durarara!!   9. Naruto   10. Elfen Lied
#
# 1. Death Note   2. Shingeki no Kyojin   3. Sen to Chihiro no Kamikakushi   4. Fullmetal Alchemist: Brotherhood   5. Steins;Gate   6. Code Geass: Hangyaku no Lelouch   7. Angel Beats!   8. Toradora!   9. Code Geass: Hangyaku no Lelouch R2   10. Sword Art Online
#
# Variety:  0.6
# Scale:  0.8333333333333334
# Threshold:  2.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Steins;Gate   3. Sword Art Online   4. Sen to Chihiro no Kamikakushi   5. Fullmetal Alchemist   6. Clannad   7. No Game No Life   8. Durarara!!   9. Clannad: After Story   10. Elfen Lied
#
# 1. Death Note   2. Shingeki no Kyojin   3. Fullmetal Alchemist: Brotherhood   4. Sen to Chihiro no Kamikakushi   5. Steins;Gate   6. Code Geass: Hangyaku no Lelouch   7. Angel Beats!   8. Toradora!   9. Code Geass: Hangyaku no Lelouch R2   10. One Punch Man
#
# Variety:  0.6
# Scale:  0.75
# Threshold:  3.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Steins;Gate   3. Sen to Chihiro no Kamikakushi   4. Sword Art Online   5. Fullmetal Alchemist   6. Clannad: After Story   7. Clannad   8. No Game No Life   9. Durarara!!   10. Bakemonogatari
#
# 1. Death Note   2. Fullmetal Alchemist: Brotherhood   3. Steins;Gate   4. Sen to Chihiro no Kamikakushi   5. Shingeki no Kyojin   6. Code Geass: Hangyaku no Lelouch   7. Toradora!   8. Angel Beats!   9. Code Geass: Hangyaku no Lelouch R2   10. One Punch Man
#
# Variety:  0.7
# Scale:  1.0
# Threshold:  0.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Sword Art Online   3. Steins;Gate   4. No Game No Life   5. Durarara!!   6. Clannad   7. Mirai Nikki (TV)   8. Sen to Chihiro no Kamikakushi   9. Tokyo Ghoul   10. Fullmetal Alchemist
#
# 1. Shingeki no Kyojin   2. Steins;Gate   3. Sen to Chihiro no Kamikakushi   4. Angel Beats!   5. Fullmetal Alchemist: Brotherhood   6. Death Note   7. Toradora!   8. Code Geass: Hangyaku no Lelouch   9. Sword Art Online   10. One Punch Man
#
# Variety:  0.7
# Scale:  0.9166666666666666
# Threshold:  1.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Steins;Gate   3. Sword Art Online   4. No Game No Life   5. Durarara!!   6. Clannad   7. Sen to Chihiro no Kamikakushi   8. Fullmetal Alchemist   9. Mirai Nikki (TV)   10. Clannad: After Story
#
# 1. Shingeki no Kyojin   2. Steins;Gate   3. Sen to Chihiro no Kamikakushi   4. Fullmetal Alchemist: Brotherhood   5. Angel Beats!   6. Death Note   7. Toradora!   8. Code Geass: Hangyaku no Lelouch   9. One Punch Man   10. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.
#
# Variety:  0.7
# Scale:  0.8333333333333334
# Threshold:  2.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Steins;Gate   3. Sword Art Online   4. No Game No Life   5. Durarara!!   6. Sen to Chihiro no Kamikakushi   7. Clannad   8. Clannad: After Story   9. Fullmetal Alchemist   10. Boku dake ga Inai Machi
#
# 1. Steins;Gate   2. Shingeki no Kyojin   3. Sen to Chihiro no Kamikakushi   4. Fullmetal Alchemist: Brotherhood   5. Angel Beats!   6. Death Note   7. Toradora!   8. Code Geass: Hangyaku no Lelouch   9. One Punch Man   10. Code Geass: Hangyaku no Lelouch R2
#
# Variety:  0.7
# Scale:  0.75
# Threshold:  3.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Steins;Gate   3. No Game No Life   4. Sen to Chihiro no Kamikakushi   5. Clannad: After Story   6. Sword Art Online   7. Durarara!!   8. Clannad   9. Fullmetal Alchemist   10. Boku dake ga Inai Machi
#
# 1. Steins;Gate   2. Fullmetal Alchemist: Brotherhood   3. Shingeki no Kyojin   4. Sen to Chihiro no Kamikakushi   5. Death Note   6. Code Geass: Hangyaku no Lelouch   7. Angel Beats!   8. Toradora!   9. One Punch Man   10. Code Geass: Hangyaku no Lelouch R2
#
# Variety:  0.8
# Scale:  1.0
# Threshold:  0.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Sword Art Online   3. No Game No Life   4. Steins;Gate   5. Noragami   6. Boku no Hero Academia   7. Tokyo Ghoul   8. Boku dake ga Inai Machi   9. Re:Zero kara Hajimeru Isekai Seikatsu   10. Mirai Nikki (TV)
#
# 1. Steins;Gate   2. Shingeki no Kyojin   3. One Punch Man   4. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.   5. Angel Beats!   6. Sen to Chihiro no Kamikakushi   7. No Game No Life   8. Toradora!   9. Fullmetal Alchemist: Brotherhood   10. Sword Art Online
#
# Variety:  0.8
# Scale:  0.9166666666666666
# Threshold:  1.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. No Game No Life   3. Steins;Gate   4. Sword Art Online   5. Boku no Hero Academia   6. Noragami   7. Boku dake ga Inai Machi   8. Tokyo Ghoul   9. Re:Zero kara Hajimeru Isekai Seikatsu   10. Durarara!!
#
# 1. Steins;Gate   2. Shingeki no Kyojin   3. One Punch Man   4. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.   5. Sen to Chihiro no Kamikakushi   6. Angel Beats!   7. No Game No Life   8. Fullmetal Alchemist: Brotherhood   9. Toradora!   10. Shigatsu wa Kimi no Uso
#
# Variety:  0.8
# Scale:  0.8333333333333334
# Threshold:  2.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Steins;Gate   3. No Game No Life   4. Sword Art Online   5. Boku no Hero Academia   6. Boku dake ga Inai Machi   7. Noragami   8. Re:Zero kara Hajimeru Isekai Seikatsu   9. Durarara!!   10. Tokyo Ghoul
#
# 1. Steins;Gate   2. Shingeki no Kyojin   3. One Punch Man   4. Sen to Chihiro no Kamikakushi   5. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.   6. Fullmetal Alchemist: Brotherhood   7. Angel Beats!   8. No Game No Life   9. Shigatsu wa Kimi no Uso   10. Toradora!
#
# Variety:  0.8
# Scale:  0.75
# Threshold:  3.0
# Penalty:  2.0
# 1. Code Geass: Hangyaku no Lelouch R2   2. Steins;Gate   3. No Game No Life   4. Boku dake ga Inai Machi   5. Boku no Hero Academia   6. Clannad: After Story   7. Re:Zero kara Hajimeru Isekai Seikatsu   8. Durarara!!   9. Noragami   10. Kiseijuu: Sei no Kakuritsu
#
# 1. Steins;Gate   2. Fullmetal Alchemist: Brotherhood   3. Shingeki no Kyojin   4. Sen to Chihiro no Kamikakushi   5. One Punch Man   6. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.   7. Shigatsu wa Kimi no Uso   8. Angel Beats!   9. No Game No Life   10. Toradora!
#
# Variety:  0.9
# Scale:  1.0
# Threshold:  0.0
# Penalty:  2.0
# 1. Boku no Hero Academia   2. Re:Zero kara Hajimeru Isekai Seikatsu   3. Nanatsu no Taizai   4. No Game No Life   5. Boku no Hero Academia 2nd Season   6. Noragami Aragoto   7. Noragami   8. Boku dake ga Inai Machi   9. Tokyo Ghoul   10. Magi: The Kingdom of Magic
#
# 1. Koe no Katachi   2. Shigatsu wa Kimi no Uso   3. Re:Zero kara Hajimeru Isekai Seikatsu   4. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.   5. Steins;Gate   6. One Punch Man   7. No Game No Life   8. Kotonoha no Niwa   9. Ookami Kodomo no Ame to Yuki   10. Steins;Gate Movie: Fuka Ryouiki no Déjà vu
#
# Variety:  0.9
# Scale:  0.9166666666666666
# Threshold:  1.0
# Penalty:  2.0
# 1. Boku no Hero Academia   2. Re:Zero kara Hajimeru Isekai Seikatsu   3. Boku no Hero Academia 2nd Season   4. No Game No Life   5. Nanatsu no Taizai   6. Noragami Aragoto   7. Noragami   8. Boku dake ga Inai Machi   9. Magi: The Kingdom of Magic   10. Ansatsu Kyoushitsu 2nd Season
#
# 1. Koe no Katachi   2. Shigatsu wa Kimi no Uso   3. Steins;Gate   4. Re:Zero kara Hajimeru Isekai Seikatsu   5. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.   6. One Punch Man   7. No Game No Life   8. Ookami Kodomo no Ame to Yuki   9. Steins;Gate Movie: Fuka Ryouiki no Déjà vu   10. Kotonoha no Niwa
#
# Variety:  0.9
# Scale:  0.8333333333333334
# Threshold:  2.0
# Penalty:  2.0
# 1. Boku no Hero Academia 2nd Season   2. Boku no Hero Academia   3. Re:Zero kara Hajimeru Isekai Seikatsu   4. No Game No Life   5. Noragami Aragoto   6. Boku dake ga Inai Machi   7. Nanatsu no Taizai   8. Ansatsu Kyoushitsu 2nd Season   9. Magi: The Kingdom of Magic   10. Noragami
#
# 1. Koe no Katachi   2. Shigatsu wa Kimi no Uso   3. Steins;Gate   4. One Punch Man   5. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.   6. Re:Zero kara Hajimeru Isekai Seikatsu   7. No Game No Life   8. Ookami Kodomo no Ame to Yuki   9. Steins;Gate Movie: Fuka Ryouiki no Déjà vu   10. Fate/Zero 2nd Season
#
# Variety:  0.9
# Scale:  0.75
# Threshold:  3.0
# Penalty:  2.0
# 1. Boku no Hero Academia 2nd Season   2. Boku no Hero Academia   3. Re:Zero kara Hajimeru Isekai Seikatsu   4. Steins;Gate   5. Boku dake ga Inai Machi   6. No Game No Life   7. Noragami Aragoto   8. Code Geass: Hangyaku no Lelouch R2   9. Ansatsu Kyoushitsu 2nd Season   10. Magi: The Kingdom of Magic
#
# 1. Koe no Katachi   2. Steins;Gate   3. Shigatsu wa Kimi no Uso   4. One Punch Man   5. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.   6. Re:Zero kara Hajimeru Isekai Seikatsu   7. Ookami Kodomo no Ame to Yuki   8. No Game No Life   9. Suzumiya Haruhi no Shoushitsu   10. Steins;Gate Movie: Fuka Ryouiki no Déjà vu

# %%
full_predict(test_users, 0.8, 4.5, 0.85, 2.5)
# Out:
# Variety:  0.85   Scale:  0.8   Threshold:  4.5   Penalty:  2.5
# 1. Steins;Gate   2. Code Geass: Hangyaku no Lelouch R2   3. Boku no Hero Academia 2nd Season   4. Boku dake ga Inai Machi   5. No Game No Life   6. Clannad: After Story   7. Re:Zero kara Hajimeru Isekai Seikatsu   8. Fate/Zero 2nd Season   9. Boku no Hero Academia   10. Kiseijuu: Sei no Kakuritsu
#
# 1. Steins;Gate   2. Koe no Katachi   3. Fullmetal Alchemist: Brotherhood   4. One Punch Man   5. Shigatsu wa Kimi no Uso   6. Sen to Chihiro no Kamikakushi   7. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.   8. Shingeki no Kyojin   9. Suzumiya Haruhi no Shoushitsu   10. Fate/Zero 2nd Season
